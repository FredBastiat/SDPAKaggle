# %%
import sys
import pip
import warnings

warnings.filterwarnings("ignore") 

print(sys.version_info)
print()

for available_distro in sorted(["%s==%s" % (i.key, i.version) for i in pip.get_installed_distributions()]):
    print(available_distro)

help('modules')
# Out:
# sys.version_info(major=2, minor=7, micro=11, releaselevel='final', serial=0)
# ()
# abstract-rendering==0.5.1
# alabaster==0.7.6
# anaconda-client==1.2.1
# argcomplete==1.0.0
# astropy==1.0.6
# babel==2.1.1
# backports-abc==0.4
# backports.ssl-match-hostname==3.4.0.2
# beautifulsoup4==4.4.1
# bitarray==0.8.1
# blaze==0.8.3
# bokeh==0.10.0
# boto==2.38.0
# bottleneck==1.0.0
# cdecimal==2.3
# cffi==1.2.1
# clyent==1.2.0
# colorama==0.3.3
# conda-build==1.18.2
# conda-env==2.4.5
# conda==3.18.8
# configobj==5.0.6
# cryptography==0.9.1
# cycler==0.9.0
# cython==0.23.4
# cytoolz==0.7.4
# datashape==0.4.7
# decorator==4.0.4
# docutils==0.12
# enum34==1.0.4
# fastcache==1.0.2
# flask==0.10.1
# funcsigs==0.4
# gevent-websocket==0.9.3
# gevent==1.0.1
# greenlet==0.4.9
# grin==1.2.1
# h5py==2.5.0
# idna==2.0
# ipaddress==1.0.14
# ipykernel==4.1.1
# ipython-genutils==0.1.0
# ipython==4.0.1
# ipywidgets==4.1.0
# itsdangerous==0.24
# jdcal==1.0
# jedi==0.9.0
# jinja2==2.8
# jsonschema==2.4.0
# jupyter-client==4.1.1
# jupyter-console==4.0.3
# jupyter-core==4.0.6
# jupyter==1.0.0
# llvmlite==0.8.0
# lxml==3.4.4
# markupsafe==0.23
# matplotlib==1.5.0
# mistune==0.7.1
# multipledispatch==0.4.8
# nbconvert==4.0.0
# nbformat==4.0.1
# networkx==1.10
# nltk==3.1
# nose==1.3.7
# notebook==4.0.6
# numba==0.22.1
# numexpr==2.4.4
# numpy==1.10.1
# odo==0.3.4
# openpyxl==2.2.6
# pandas==0.17.1
# path.py==0.0.0
# patsy==0.4.0
# pep8==1.6.2
# pexpect==3.3
# pickleshare==0.5
# pillow==3.0.0
# pip==8.0.2
# ply==3.8
# psutil==3.3.0
# ptyprocess==0.5
# py==1.4.30
# pyasn1==0.1.9
# pycairo==1.10.0
# pycosat==0.6.1
# pycparser==2.14
# pycrypto==2.6.1
# pycurl==7.19.5.1
# pyflakes==1.0.0
# pygments==2.0.2
# pyopenssl==0.15.1
# pyparsing==2.0.3
# pytest==2.8.1
# python-dateutil==2.4.2
# pytz==2015.7
# pyyaml==3.11
# pyzmq==14.7.0
# qtconsole==4.1.1
# requests==2.8.1
# rope==0.9.4
# scikit-image==0.11.3
# scikit-learn==0.17
# scipy==0.16.0
# setuptools==18.5
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.10.0
# snowballstemmer==1.2.0
# sockjs-tornado==1.0.1
# sphinx-rtd-theme==0.1.7
# sphinx==1.3.1
# spyder==2.3.8
# sqlalchemy==1.0.9
# statsmodels==0.6.1
# sympy==0.7.6.1
# tables==3.2.2
# terminado==0.5
# theano==0.7.0
# toolz==0.7.4
# tornado==4.3
# traitlets==4.0.0
# ujson==1.33
# unicodecsv==0.14.1
# werkzeug==0.11.2
# wheel==0.26.0
# xlrd==0.9.4
# xlsxwriter==0.7.7
# xlwt==1.0.0
#
# Please wait a moment while I gather a list of all available modules...
#
# ANSI                bs4                 jupyter_client      setuptools
# BaseHTTPServer      bsddb               jupyter_console     sgmllib
# Bastion             bz2                 jupyter_core        sha
# CDROM               cPickle             keyword             shelve
# CGIHTTPServer       cProfile            lib2to3             shlex
# Canvas              cStringIO           linecache           shutil
# ConfigParser        cairo               linuxaudiodev       signal
# Cookie              calendar            llvmlite            simplegeneric
# Crypto              cdecimal            locale              singledispatch
# Cython              cffi                logging             singledispatch_helpers
# DLFCN               cgi                 lxml                sip
# Dialog              cgitb               macpath             sipconfig
# DocXMLRPCServer     chunk               macurl2path         sipdistutils
# FSM                 clyent              mailbox             site
# FileDialog          cmath               mailcap             six
# FixTk               cmd                 markupbase          skimage
# HTMLParser          code                markupsafe          sklearn
# IN                  codecs              marshal             smtpd
# IPython             codeop              math                smtplib
# MimeWriter          collections         matplotlib          sndhdr
# OpenSSL             colorama            md5                 snowballstemmer
# PIL                 colorsys            mhlib               socket
# PyQt4               command             mimetools           sockjs
# Queue               commands            mimetypes           sphinx
# ScrolledText        compileall          mimify              sphinx_rtd_theme
# SimpleDialog        compiler            mistune             spwd
# SimpleHTTPServer    conda               mmap                spyderlib
# SimpleXMLRPCServer  conda_build         modulefinder        spyderplugins
# SocketServer        conda_env           mpl_toolkits        sqlalchemy
# StringIO            configobj           multifile           sqlite3
# TYPES               contextlib          multipledispatch    sre
# Tix                 cookielib           multiprocessing     sre_compile
# Tkconstants         copy                mutex               sre_constants
# Tkdnd               copy_reg            nbconvert           sre_parse
# Tkinter             crypt               nbformat            ssl
# UserDict            cryptography        netrc               stat
# UserList            csv                 networkx            statsmodels
# UserString          ctypes              new                 statvfs
# _LWPCookieJar       curl                nis                 storemagic
# _MozillaCookieJar   curses              nltk                string
# __builtin__         cycler              nntplib             stringold
# __future__          cython              nose                stringprep
# _abcoll             cythonmagic         notebook            strop
# _ast                cytoolz             ntpath              struct
# _bisect             datashape           nturl2path          subprocess
# _cffi_backend       datetime            numba               sunau
# _codecs             dateutil            numbers             sunaudio
# _codecs_cn          dbhash              numexpr             symbol
# _codecs_hk          decimal             numpy               sympy
# _codecs_iso2022     decorator           odo                 sympyprinting
# _codecs_jp          difflib             opcode              symtable
# _codecs_kr          dircache            openpyxl            sys
# _codecs_tw          dis                 operator            sysconfig
# _collections        distutils           optparse            syslog
# _csv                dl                  os                  tables
# _ctypes             doctest             os2emxpath          tabnanny
# _ctypes_test        docutils            ossaudiodev         tarfile
# _curses             dumbdbm             pandas              telnetlib
# _curses_panel       dummy_thread        parser              tempfile
# _elementtree        dummy_threading     path                terminado
# _functools          easy_install        patsy               termios
# _hashlib            email               pdb                 test_path
# _heapq              encodings           pep8                test_pycosat
# _hotshot            enum                pexpect             tests
# _io                 errno               pickle              textwrap
# _json               et_xmfile           pickleshare         theano
# _license            exceptions          pickletools         this
# _locale             fastcache           pip                 thread
# _lsprof             fcntl               pipes               threading
# _markerlib          fdpexpect           pkg_resources       time
# _multibytecodec     filecmp             pkgutil             timeit
# _multiprocessing    fileinput           platform            tkColorChooser
# _osx_support        flask               plistlib            tkCommonDialog
# _pyio               fnmatch             ply                 tkFileDialog
# _pytest             formatter           popen2              tkFont
# _random             fpformat            poplib              tkMessageBox
# _socket             fractions           posix               tkSimpleDialog
# _sqlite3            ftplib              posixfile           toaiff
# _sre                funcsigs            posixpath           token
# _ssl                functools           pprint              tokenize
# _strptime           future_builtins     profile             toolz
# _struct             gc                  pstats              tornado
# _symtable           genericpath         psutil              trace
# _sysconfigdata      getopt              pty                 traceback
# _testcapi           getpass             ptyprocess          traitlets
# _threading_local    gettext             pwd                 ttk
# _tkinter            gevent              pxssh               tty
# _vendor             geventwebsocket     py                  turtle
# _version            glob                py_compile          types
# _warnings           greenlet            pyasn1              ujson
# _weakref            grin                pyclbr              unicodecsv
# _weakrefset         grp                 pycosat             unicodedata
# _yaml               gzip                pycparser           unittest
# abc                 h5py                pycurl              urllib
# abstract_rendering  hashlib             pydoc               urllib2
# aifc                heapq               pydoc_data          urlparse
# alabaster           hmac                pyexpat             user
# antigravity         hotshot             pyflakes            uu
# anydbm              htmlentitydefs      pygments            uuid
# argcomplete         htmllib             pylab               validate
# argparse            httplib             pyparsing           warnings
# array               idlelib             pytest              wave
# ast                 idna                pytz                weakref
# astropy             ihooks              pyximport           webbrowser
# asynchat            imageop             qtconsole           werkzeug
# asyncore            imaplib             quopri              wheel
# atexit              imghdr              random              whichdb
# audiodev            imp                 re                  wsgiref
# audioop             importlib           readline            xdrlib
# autoreload          imputil             repr                xlrd
# babel               inspect             requests            xlsxwriter
# backports           io                  resource            xlwt
# backports_abc       ipaddress           rexec               xml
# base64              ipykernel           rfc822              xmllib
# bdb                 ipython_genutils    rlcompleter         xmlrpclib
# binascii            ipywidgets          rmagic              xxsubtype
# binhex              itertools           robotparser         yaml
# binstar_client      itsdangerous        rope                zipfile
# bisect              jdcal               runpy               zipimport
# bitarray            jedi                sched               zlib
# blaze               jinja2              scipy               zmq
# bokeh               json                screen
# boto                jsonschema          select
# bottleneck          jupyter             sets
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose descriptions contain the word "spam".
